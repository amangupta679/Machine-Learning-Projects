# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
dataset=pd.read_csv('/content/drive/My Drive/Colab Notebooks/ML/Social_Network_Ads.csv')
dataset.shape
# Out:
# (400, 5)

# %%
dataset.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
sns.countplot(x='Gender',hue='Purchased',data=dataset)

# %%
dataset['EstimatedSalary'].plot.hist()

# %%
plt.scatter(dataset['EstimatedSalary'],dataset['Purchased'])

# %%
dataset.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.boxplot(y='EstimatedSalary',x='Age',data=dataset)

# %%
dataset['Purchased'].value_counts().plot(kind='barh')

# %%
X=dataset.iloc[:,[2,3]].values
Y=dataset.iloc[:,4].values

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
X_train=sc.fit_transform(X_train)
X_test=sc.transform(X_test)

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
Y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
accuracy_score(Y_test,Y_pred)
# Out:
# 0.85

# %%
confusion_matrix(Y_test,Y_pred)
# Out:
# array([[52,  1],
#        [11, 16]])
