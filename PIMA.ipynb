# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
columns=['Pregnant','Plasma-Glucose-Concentration','Diastolic BP','Triceps SFT','Insulin','BMI','DPF','Age','Res']
dataset=pd.read_csv('/content/drive/My Drive/Colab Notebooks/ML/pima-indians-diabetes.csv',names=columns)
dataset.shape
# Out:
# (768, 9)

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
# Pregnant                        768 non-null int64
# Plasma-Glucose-Concentration    768 non-null int64
# Diastolic BP                    768 non-null int64
# Triceps SFT                     768 non-null int64
# Insulin                         768 non-null int64
# BMI                             768 non-null float64
# DPF                             768 non-null float64
# Age                             768 non-null int64
# Res                             768 non-null int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
dataset.head()
# Out:
#    Pregnant  Plasma-Glucose-Concentration  Diastolic BP  ...    DPF  Age  Res
# 0         6                           148            72  ...  0.627   50    1
# 1         1                            85            66  ...  0.351   31    0
# 2         8                           183            64  ...  0.672   32    1
# 3         1                            89            66  ...  0.167   21    0
# 4         0                           137            40  ...  2.288   33    1
#
# [5 rows x 9 columns]

# %%
sns.countplot(x='Pregnant',hue='Res',data=dataset)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 59

# %%
dataset['Diastolic BP'].plot.hist()

# %%
plt.figure(figsize=(20,10))
plt.scatter(x=dataset['BMI'],y=dataset['Diastolic BP'])
